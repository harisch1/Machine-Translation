# %%
from util import prepareData as DataLoader

# %%
input_lang, output_lang, pairs = DataLoader('eng', 'fra', True)
# Out:
# Reading lines...
# Read 135842 sentence pairs
# Trimmed to 11445 sentence pairs
# Counting words...
# Counted words:
# fra 4601
# eng 2991

# %%
input_lang.word2count
# Out:
# {'je': 4188,
#  'vais': 286,
#  'bien': 128,
#  'ca': 132,
#  'va': 65,
#  'suis': 2891,
#  'gras': 6,
#  'gros': 15,
#  'en': 959,
#  'forme': 18,
#  'touche': 4,
#  '!': 205,
#  'touchee': 2,
#  'malade': 27,
#  'triste': 14,
#  'timide': 18,
#  'mouille': 2,
#  'mouillee': 1,
#  'il': 1422,
#  'est': 1975,
#  'revenu': 3,
#  'me': 314,
#  'revoila': 1,
#  'chauve': 3,
#  'occupe': 60,
#  'occupee': 37,
#  'calme': 4,
#  'j': 475,
#  'ai': 422,
#  'froid': 14,
#  'fini': 57,
#  'tout': 167,
#  'libre': 28,
#  'disponible': 7,
#  'repu': 1,
#  'rassasie': 3,
#  'content': 74,
#  'chez': 58,
#  'moi': 226,
#  'retard': 52,
#  'paresseux': 12,
#  'faineant': 4,
#  'paresseuse': 5,
#  'faineante': 3,
#  'porte': 37,
#  'securite': 36,
#  'certain': 39,
#  'sur': 180,
#  'sure': 49,
#  'grande': 36,
#  'mince': 5,
#  'ordonne': 4,
#  'ordonnee': 3,
#  'laid': 3,
#  'laide': 2,
#  'faible': 9,
#  'vieux': 71,
#  'dj': 2,
#  'bon': 109,
#  'riche': 26,
#  'ici': 188,
#  'flic': 2,
# ...
